# %%
# Import required libraries
import numpy as np
import pandas as pd
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split

# %%
#Load the data
HRV = pd.read_csv('/Users/aguetat/Desktop/train.csv')
HRV.head(10)
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  885.157845  853.763730  140.972741  15.554505  15.553371    9.063146
# 1  939.425371  948.357865   81.317742  12.964439  12.964195    6.272369
# 2  898.186047  907.006860   84.497236  16.305279  16.305274    5.182201
# 3  881.757865  893.460030   90.370537  15.720468  15.720068    5.748591
# 4  809.625331  811.184865   62.766242  19.213819  19.213657    3.266724
# 5  923.283866  617.794160  517.536544   9.965976   9.933933   51.930344
# 6  973.252908  964.650020   82.405179  10.644196  10.643638    7.741794
# 7  715.914682  679.499395  131.477151   9.477727   9.477717   13.872224
# 8  814.257021  827.522830   87.014459  14.632232  14.631275    5.946766
# 9  959.694591  957.895600   54.904529  12.015400  12.015343    4.569513
#
#           HR      pNN25     pNN50        SD1  ...         HF    HF_PCT  \
# 0  69.499952  11.133333  0.533333  11.001565  ...  15.522603  0.421047
# ...

# %%
# DATA EXPLORATION
conditions = HRV.groupby('condition')
print(conditions.groups)
#conditions.value_counts()
# Out:
# {'interruption': Int64Index([     1,      2,      8,     13,     19,     23,     24,     25,
#                 26,     32,
#             ...
#             369236, 369239, 369240, 369251, 369252, 369262, 369263, 369265,
#             369273, 369282],
#            dtype='int64', length=105150), 'no stress': Int64Index([     0,      3,      4,      5,      6,      7,      9,     11,
#                 12,     14,
#             ...
#             369276, 369277, 369278, 369279, 369281, 369284, 369285, 369286,
#             369287, 369288],
#            dtype='int64', length=200082), 'time pressure': Int64Index([    10,     18,     22,     28,     35,     36,     40,     58,
#                 60,     70,
#             ...
#             369198, 369199, 369237, 369247, 369249, 369264, 369267, 369275,
#             369280, 369283],
#            dtype='int64', length=64057)}

# %%
conditions2 = HRV.groupby(['condition','HR'])
print(conditions2.groups)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
conditions3 = HRV.groupby(['condition','datasetId'])
print(conditions3.groups)
# Out:
# {('interruption', 2): Int64Index([     1,      2,      8,     13,     19,     23,     24,     25,
#                 26,     32,
#             ...
#             369236, 369239, 369240, 369251, 369252, 369262, 369263, 369265,
#             369273, 369282],
#            dtype='int64', length=105150), ('no stress', 2): Int64Index([     0,      3,      4,      5,      6,      7,      9,     11,
#                 12,     14,
#             ...
#             369276, 369277, 369278, 369279, 369281, 369284, 369285, 369286,
#             369287, 369288],
#            dtype='int64', length=200082), ('time pressure', 2): Int64Index([    10,     18,     22,     28,     35,     36,     40,     58,
#                 60,     70,
#             ...
#             369198, 369199, 369237, 369247, 369249, 369264, 369267, 369275,
#             369280, 369283],
#            dtype='int64', length=64057)}
